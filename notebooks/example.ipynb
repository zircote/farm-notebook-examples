# %% [markdown]
# # Example Notebook
#
# This is a template notebook demonstrating best practices for organizing experiments and learning projects.
#
# ## Purpose
#
# Describe what this notebook explores or accomplishes.

# %% [markdown]
# ## Setup
#
# Import required libraries and configure the environment.

# %%
# Standard library imports
from datetime import datetime
from pathlib import Path

# Third-party imports (uncomment as needed)
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# Configuration
print(f"Notebook started: {datetime.now().isoformat()}")

# %% [markdown]
# ## Data Loading
#
# Load and preview the data.

# %%
# Example: Load data
# raw_data = pd.read_csv("data/input.csv")
# raw_data.head()

# Placeholder for your data loading code
sample_data = {"name": ["Alice", "Bob", "Charlie"], "value": [10, 20, 30]}
sample_data

# %% [markdown]
# ## Analysis
#
# Perform the main analysis or experiment.

# %%
# Example analysis
total = sum(sample_data["value"])
average = total / len(sample_data["value"])

print(f"Total: {total}")
print(f"Average: {average}")

# %% [markdown]
# ## Visualization
#
# Create visualizations to understand the data.

# %%
# Example visualization (uncomment when matplotlib is available)
# fig, ax = plt.subplots(figsize=(8, 5))
# ax.bar(sample_data["name"], sample_data["value"])
# ax.set_title("Sample Values by Name")
# ax.set_xlabel("Name")
# ax.set_ylabel("Value")
# plt.tight_layout()
# plt.show()

print("Visualization placeholder - install matplotlib with: uv sync --extra data")

# %% [markdown]
# ## Conclusion
#
# Summarize the findings and next steps.
#
# ### Key Findings
#
# - Finding 1
# - Finding 2
# - Finding 3
#
# ### Next Steps
#
# - [ ] Next step 1
# - [ ] Next step 2
